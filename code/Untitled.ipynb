# %%
import pandas as pd
import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From C:\Users\m6zha\Anaconda3\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
! pip install tensorflow

# %%
review = pd.read_csv('../data/year_2018.csv')

# %%
review.head()
# Out:
#    Unnamed: 0  overall  vote  verified  reviewTime      reviewerID  \
# 0     6739449      5.0   NaN      True  2018-10-04  A2IXGBWKX73O21
# 1     6739257      5.0   NaN      True  2018-10-04   AHEX3FYTJ2AX6
# 2     6738877      3.0   NaN     False  2018-10-03  A2J77LP43D7QMX
# 3     6739102      5.0   NaN      True  2018-10-03  A32FN9RNY65CKH
# 4     6735704      5.0   NaN      True  2018-10-02  A2ZE26LV7HVSAD
#
#          asin                                              style  \
# 0  B01HI7D4VY                                                NaN
# 1  B01HH36F74                               {'Color:': ' CA100'}
# 2  B01HF0YGCK                               {'Color:': ' Black'}
# 3  B01HGF6XTI                              {'Size:': ' Charger'}
# 4  B01GUITK24  {'Style Name:': ' Bookshelf Speaker Mount 2 Pa...
#
#                                           reviewText  \
# 0                               quality, very bright
# 1                                 Works as expected.
# ...

# %%
review.drop(['Unnamed: 0'], axis = 1,inplace = True)
review.rename(columns={'overall':'individual_rating'}, inplace=True)

# %%
review.head()
# Out:
#    individual_rating  vote  verified  reviewTime      reviewerID        asin  \
# 0                5.0   NaN      True  2018-10-04  A2IXGBWKX73O21  B01HI7D4VY
# 1                5.0   NaN      True  2018-10-04   AHEX3FYTJ2AX6  B01HH36F74
# 2                3.0   NaN     False  2018-10-03  A2J77LP43D7QMX  B01HF0YGCK
# 3                5.0   NaN      True  2018-10-03  A32FN9RNY65CKH  B01HGF6XTI
# 4                5.0   NaN      True  2018-10-02  A2ZE26LV7HVSAD  B01GUITK24
#
#                                                style  \
# 0                                                NaN
# 1                               {'Color:': ' CA100'}
# 2                               {'Color:': ' Black'}
# 3                              {'Size:': ' Charger'}
# 4  {'Style Name:': ' Bookshelf Speaker Mount 2 Pa...
#
#                                           reviewText  \
# 0                               quality, very bright
# 1                                 Works as expected.
# ...

# %%
review_user=review[['individual_rating','asin','reviewerID']]

# %%
review_user['asin'].nunique()
# Out:
# 56675

# %%
totalusers = 338658
X=[]
for userID, curuser in review_user:
    temp = [0]*56675
# Out:
#        Unnamed: 0  index        asin  \
# 0               0    639  B01HJDR9DQ
# 1               1    371  B01HJA3OUG
# 2               2    205  B01HIZEW1C
# 3               4    696  B01HIURQWE
# 4               5    245  B01HIS5O7A
# ...           ...    ...         ...
# 10905       13855    904  B009IESEBQ
# 10906       13856     74  B008ITQIMO
# 10907       13857    613  B005ODJO32
# 10908       13858    637  B004IA9XLU
# 10909       13859    398  B0048ODJ3Y
#
#                                             product_name    product_brand  \
# 0      Geilienergy BT-17333 BT-27333 Handset Telephon...      GEILIENERGY
# 1      LETOUR DC 5V 30A Power Supply 150W AC 110V/220...           LETOUR
# 2      AmazonBasics DSLR Camera and Laptop Backpack B...     AmazonBasics
# 3      Dmax Armor for LG G Pad X 10.1 Screen Protecto...       Dmax Armor
# 4                       Polk Audio BITB-A Boom Bit Black        Polk BOOM
# ...

# %%
hidden_units = 40
visible_units = 56675
visible = tf.placeholder('float',[visible_units])
hidden = tf.placehoder('float',[hidden_units])
W - tf.placeholder('float',[visible_units, hidden_units])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-217746aac879> in <module>
#       2 visible_units = 56675
#       3 visible = tf.placeholder('float',[visible_units])
# ----> 4 hidden = tf.placehoder('float',[hidden_units])
#       5 W - tf.placeholder('float',[visible_units, hidden_units])
#
# AttributeError: module 'tensorflow_core.compat.v1' has no attribute 'placehoder'
