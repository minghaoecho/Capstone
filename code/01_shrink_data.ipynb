# %%
import json
import pandas as pd

# %%
df = {}
i=0
for line in open('../data/Electronics_5.json/Electronics_5.json', 'r'):
    df[i]=json.loads(line)
    i+=1

df = pd.DataFrame.from_dict(df, orient='index')
df.to_csv('../data/1st_draft.csv')
df.head()
# with open('../data/Electronics_5.json/Electronics_5.json') as f:
# data = json.load(f)
# Out:
#    overall vote  verified   reviewTime      reviewerID        asin  \
# 0      5.0   67      True  09 18, 1999   AAP7PPBU72QFM  0151004714
# 1      3.0    5      True  10 23, 2013  A2E168DTVGE6SV  0151004714
# 2      5.0    4     False   09 2, 2008  A1ER5AYS3FQ9O3  0151004714
# 3      5.0   13     False   09 4, 2000  A1T17LMQABMBN5  0151004714
# 4      3.0    8      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
#
#                             style      reviewerName  \
# 0       {'Format:': ' Hardcover'}      D. C. Carrad
# 1  {'Format:': ' Kindle Edition'}               Evy
# 2       {'Format:': ' Paperback'}             Kcorn
# 3       {'Format:': ' Hardcover'}   Caf Girl Writes
# 4       {'Format:': ' Hardcover'}  W. Shane Schmidt
#
#                                           reviewText  \
# 0  This is the best novel I have read in 2 or 3 y...
# 1  Pages and pages of introspection, in the style...
# 2  This is the kind of novel to read when you hav...
# ...

# %%
df.head(50)
# Out:
#     Unnamed: 0  overall vote  verified   reviewTime      reviewerID  \
# 0            0      5.0   67      True  09 18, 1999   AAP7PPBU72QFM
# 1            1      3.0    5      True  10 23, 2013  A2E168DTVGE6SV
# 2            2      5.0    4     False   09 2, 2008  A1ER5AYS3FQ9O3
# 3            3      5.0   13     False   09 4, 2000  A1T17LMQABMBN5
# 4            4      3.0    8      True   02 4, 2000  A3QHJ0FXK33OBE
# 5            5      4.0  NaN      True   06 5, 2013  A3IYSOTP3HA77N
# 6            6      5.0  NaN      True  06 27, 2016  A11SXV34PZUQ5E
# 7            7      5.0  NaN      True  07 30, 2015  A2AUQM1HT2D5T8
# 8            8      5.0  NaN      True  02 16, 2015  A3UD8JRWLX6SRX
# 9            9      4.0  NaN     False  11 21, 2013  A3MV1KKHX51FYT
# 10          10      5.0  NaN     False  07 14, 2009  A3LXXYBYUHZWS5
# 11          11      5.0  NaN     False  07 10, 2009  A1X4L7AO1BXMHK
# 12          12      3.0  NaN     False   09 2, 2009  A1Y9RUTH5GG3MU
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6739590 entries, 0 to 6739589
# Data columns (total 13 columns):
# Unnamed: 0        int64
# overall           float64
# vote              object
# verified          bool
# reviewTime        object
# reviewerID        object
# asin              object
# style             object
# reviewerName      object
# reviewText        object
# summary           object
# unixReviewTime    int64
# image             object
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 623.5+ MB

# %%
df['asin'].nunique()
# Out:
# 160052

# %%
df.drop(['Unnamed: 0','reviewerName','unixReviewTime','image'],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    overall vote  verified   reviewTime      reviewerID        asin  \
# 0      5.0   67      True  09 18, 1999   AAP7PPBU72QFM  0151004714
# 1      3.0    5      True  10 23, 2013  A2E168DTVGE6SV  0151004714
# 2      5.0    4     False   09 2, 2008  A1ER5AYS3FQ9O3  0151004714
# 3      5.0   13     False   09 4, 2000  A1T17LMQABMBN5  0151004714
# 4      3.0    8      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
#
#                             style  \
# 0       {'Format:': ' Hardcover'}
# 1  {'Format:': ' Kindle Edition'}
# 2       {'Format:': ' Paperback'}
# 3       {'Format:': ' Hardcover'}
# 4       {'Format:': ' Hardcover'}
#
#                                           reviewText  \
# 0  This is the best novel I have read in 2 or 3 y...
# 1  Pages and pages of introspection, in the style...
# 2  This is the kind of novel to read when you hav...
# 3  What gorgeous language! What an incredible wri...
# 4  I was taken in by reviews that compared this b...
#
# ...

# %%
df['reviewTime'] = pd.to_datetime(df['reviewTime'])

# %%
df.head(5)
# Out:
#    overall vote  verified reviewTime      reviewerID        asin  \
# 0      5.0   67      True 1999-09-18   AAP7PPBU72QFM  0151004714
# 1      3.0    5      True 2013-10-23  A2E168DTVGE6SV  0151004714
# 2      5.0    4     False 2008-09-02  A1ER5AYS3FQ9O3  0151004714
# 3      5.0   13     False 2000-09-04  A1T17LMQABMBN5  0151004714
# 4      3.0    8      True 2000-02-04  A3QHJ0FXK33OBE  0151004714
#
#                             style  \
# 0       {'Format:': ' Hardcover'}
# 1  {'Format:': ' Kindle Edition'}
# 2       {'Format:': ' Paperback'}
# 3       {'Format:': ' Hardcover'}
# 4       {'Format:': ' Hardcover'}
#
#                                           reviewText  \
# 0  This is the best novel I have read in 2 or 3 y...
# 1  Pages and pages of introspection, in the style...
# 2  This is the kind of novel to read when you hav...
# 3  What gorgeous language! What an incredible wri...
# 4  I was taken in by reviews that compared this b...
#
# ...

# %%
df.to_csv('../data/2nd_draft.csv')

# %%
df = df.sort_values(by = ['reviewTime'], ascending = False)

# %%
df.head(20)
# Out:
#          overall vote  verified reviewTime      reviewerID        asin  \
# 6739449      5.0  NaN      True 2018-10-04  A2IXGBWKX73O21  B01HI7D4VY
# 6739257      5.0  NaN      True 2018-10-04   AHEX3FYTJ2AX6  B01HH36F74
# 6738877      3.0  NaN     False 2018-10-03  A2J77LP43D7QMX  B01HF0YGCK
# 6739102      5.0  NaN      True 2018-10-03  A32FN9RNY65CKH  B01HGF6XTI
# 6735704      5.0  NaN      True 2018-10-02  A2ZE26LV7HVSAD  B01GUITK24
# 6738616      4.0  NaN      True 2018-10-02  A3PZOXWYTW5ZAW  B01HDUTJ88
# 6736277      2.0  NaN      True 2018-10-02  A2U26O5EYD1RB4  B01GZRIJRC
# 6738809      2.0  NaN      True 2018-10-02  A22TE5RFEO9KV9  B01HETFQA8
# 6738105      4.0  NaN      True 2018-10-02  A2950YNNOUAFH4  B01HB9J6NO
# 6737679      5.0  NaN      True 2018-10-02   A7AMHY2SAI0LT  B01H8314J2
# 6733872      5.0  NaN      True 2018-10-01   ACU9VBNGLIN46  B01GHTVNSK
# 6737860      5.0  NaN      True 2018-10-01   AW41EMQ7GAETW  B01H9TA1T4
# ...

# %%
df.to_csv('../data/3rd_draft.csv')

# %%
after_2010 = df[df['reviewTime'].dt.year >= 2010]
after_2010.head(20)
# Out:
#          overall vote  verified reviewTime      reviewerID        asin  \
# 6739449      5.0  NaN      True 2018-10-04  A2IXGBWKX73O21  B01HI7D4VY
# 6739257      5.0  NaN      True 2018-10-04   AHEX3FYTJ2AX6  B01HH36F74
# 6738877      3.0  NaN     False 2018-10-03  A2J77LP43D7QMX  B01HF0YGCK
# 6739102      5.0  NaN      True 2018-10-03  A32FN9RNY65CKH  B01HGF6XTI
# 6735704      5.0  NaN      True 2018-10-02  A2ZE26LV7HVSAD  B01GUITK24
# 6738616      4.0  NaN      True 2018-10-02  A3PZOXWYTW5ZAW  B01HDUTJ88
# 6736277      2.0  NaN      True 2018-10-02  A2U26O5EYD1RB4  B01GZRIJRC
# 6738809      2.0  NaN      True 2018-10-02  A22TE5RFEO9KV9  B01HETFQA8
# 6738105      4.0  NaN      True 2018-10-02  A2950YNNOUAFH4  B01HB9J6NO
# 6737679      5.0  NaN      True 2018-10-02   A7AMHY2SAI0LT  B01H8314J2
# 6733872      5.0  NaN      True 2018-10-01   ACU9VBNGLIN46  B01GHTVNSK
# 6737860      5.0  NaN      True 2018-10-01   AW41EMQ7GAETW  B01H9TA1T4
# ...

# %%
after_2010.to_csv('../data/after_2010.csv')

# %%
after_2010.shape
# Out:
# (6437155, 9)

# %%
after_2013 = df[df['reviewTime'].dt.year >= 2013]
after_2013.shape
# Out:
# (5838960, 9)

# %%
after_2013.to_csv('../data/after_2013.csv')

# %%
after_2013['asin'].nunique()
# Out:
# 154889

# %%
year_2018 = df[df['reviewTime'].dt.year == 2018]
year_2018.shape
# Out:
# (377430, 9)

# %%
year_2018['asin'].nunique()
# Out:
# 56675

# %%
year_2018.to_csv('../data/year_2018.csv')

# %%
year_2017 = df[df['reviewTime'].dt.year == 2017]
year_2017.shape
# Out:
# (912915, 9)

# %%
year_2017.head()
# Out:
#          overall vote  verified reviewTime      reviewerID        asin  \
# 4960716      3.0  NaN     False 2017-12-31  A1UCND9VVG3OXA  B00SLVB71Q
# 6672161      5.0  NaN      True 2017-12-31  A2XRMQA6PJ5ZJ8  B015S3CFM4
# 3448302      5.0  NaN      True 2017-12-31   AZHTDLJQ9HFRT  B00D7KP8S4
# 1655697      4.0  NaN      True 2017-12-31   AATHANUQFDGSX  B003OBUJIK
# 5278636      4.0  NaN      True 2017-12-31  A3DNGKONK7CILH  B00YBBUY6O
#
#                                             style  \
# 4960716  {'Color:': ' Single Driver IEM (Smoke)'}
# 6672161                                       NaN
# 3448302                                       NaN
# 1655697  {'Package Type:': ' Standard Packaging'}
# 5278636     {'Length:': ' 75FT + Signal Booster'}
#
#                                                 reviewText  \
# 4960716  I've only owned full sized headphones (hd600/6...
# 6672161  This product is exactly what I wanted for my i...
# ...

# %%
year_2017.tail()
# Out:
#          overall vote  verified reviewTime      reviewerID        asin  \
# 500613       4.0  NaN     False 2017-01-01  A2DIQTZPF26T1L  B000HCGAFK
# 4670061      5.0  NaN      True 2017-01-01  A2AN1A3Q08SJFG  B00NODE1VY
# 5883288      5.0  NaN      True 2017-01-01  A31VS7SBER8RBU  B01CI5LLUC
# 3341794      5.0  NaN      True 2017-01-01  A1QJOGFZNI3XJZ  B00CFLBU88
# 1945208      5.0  NaN      True 2017-01-01  A1OPJJE7FCQ8PV  B004RORMF6
#
#                                             style  \
# 500613                                        NaN
# 4670061               {'Color:': ' Black Chrome'}
# 5883288               {'Length:': ' Black 12pcs'}
# 3341794  {'Size:': ' 6 Feet', 'Color:': ' Black'}
# 1945208                    {'Capacity:': ' 1 TB'}
#
#                                                 reviewText  \
# 500613   last summer when my uncle was out visiting he ...
# 4670061         Looks great and no leaks. Would buy again.
# ...

# %%
year_2017.to_csv('../data/year_2017.csv')

# %%
year_2016 = df[df['reviewTime'].dt.year == 2016]
year_2016.shape
# Out:
# (1426496, 9)

# %%
year_2016.to_csv('../data/year_2016.csv')

# %%
year_2015 = df[df['reviewTime'].dt.year == 2015]
year_2015.shape
# Out:
# (1441804, 9)

# %%
year_2015.to_csv('../data/year_2015.csv')

# %%
year_2014 = df[df['reviewTime'].dt.year == 2014]
year_2014.shape
# Out:
# (1034835, 9)

# %%
year_2014.to_csv('../data/year_2014.csv')

# %%
year_2013 = df[df['reviewTime'].dt.year == 2013]
year_2013.shape
# Out:
# (645480, 9)

# %%
year_2013.to_csv('../data/year_2013.csv')

# %%
df=pd.read_csv('../data/3rd_draft.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  overall vote  verified reviewTime      reviewerID        asin  \
# 0     6739449      5.0  NaN      True 2018-10-04  A2IXGBWKX73O21  B01HI7D4VY
# 1     6739257      5.0  NaN      True 2018-10-04   AHEX3FYTJ2AX6  B01HH36F74
# 2     6738877      3.0  NaN     False 2018-10-03  A2J77LP43D7QMX  B01HF0YGCK
# 3     6739102      5.0  NaN      True 2018-10-03  A32FN9RNY65CKH  B01HGF6XTI
# 4     6735704      5.0  NaN      True 2018-10-02  A2ZE26LV7HVSAD  B01GUITK24
#
#                                                style  \
# 0                                                NaN
# 1                               {'Color:': ' CA100'}
# 2                               {'Color:': ' Black'}
# 3                              {'Size:': ' Charger'}
# 4  {'Style Name:': ' Bookshelf Speaker Mount 2 Pa...
#
#                                           reviewText  \
# 0                               quality, very bright
# 1                                 Works as expected.
# ...

# %%
df.shape
# Out:
# (6739590, 10)

# %%
df['reviewTime'] = pd.to_datetime(df['reviewTime'])

# %%
df_2018 = df[df['reviewTime'].dt.year == 2018]

# %%
df_2018['reviewerID'].nunique()
# Out:
# 168153

# %%
df_2018['asin'].nunique()
# Out:
# 56675

# %%
#df['reviewerID'].groupby([df.reviewTime.dt.year]).agg('count').nunique()
# Out:
# 20

# %%
import matplotlib.pyplot as plt

# %%
review_time = pd.DataFrame(df['reviewTime'].groupby([df.reviewTime.dt.year]).agg('count'))
review_time
# Out:
#             reviewTime
# reviewTime
# 1999                95
# 2000               860
# 2001              1811
# 2002              2718
# 2003              4218
# 2004              6513
# 2005             12180
# 2006             20820
# 2007             50201
# 2008             88428
# 2009            114591
# 2010            122788
# 2011            178487
# 2012            296920
# 2013            645480
# 2014           1034835
# 2015           1441804
# 2016           1426496
# 2017            912915
# 2018            377430

# %%
review_time.rename(columns={'reviewTime':'count'},inplace = True)

# %%
review_time.reset_index()
# Out:
#     reviewTime    count
# 0         1999       95
# 1         2000      860
# 2         2001     1811
# 3         2002     2718
# 4         2003     4218
# 5         2004     6513
# 6         2005    12180
# 7         2006    20820
# 8         2007    50201
# 9         2008    88428
# 10        2009   114591
# 11        2010   122788
# 12        2011   178487
# 13        2012   296920
# 14        2013   645480
# 15        2014  1034835
# 16        2015  1441804
# 17        2016  1426496
# 18        2017   912915
# 19        2018   377430
